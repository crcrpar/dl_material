# %%
# %matplotlib inline
import numpy as np
import scipy
import matplotlib.pyplot as plt

def gen_random(loc, size):
    return list(np.random.normal(loc=loc, scale=0.25, size=size))

# fig 1
x0, x5, x00, x55 = gen_random(0.0, 100), gen_random(5.0, 100), gen_random(0.0, 100), gen_random(5.0, 100)
a_x = x0 + x5
a_y = x00 + x55
b_x = x5 + x0
b_y = x0 + x5
x= np.linspace(0.0, 5.0, 100)
y = x - 0.5
group_a = plt.scatter(a_x, a_y, alpha=0.6)
group_b = plt.scatter(b_x, b_y, alpha=0.6)
plt.plot(x, y, 'g', label='bound')
plt.legend((group_a, group_b), ('group A', 'group B'), bbox_to_anchor=(1.3, 1))
plt.legend()
plt.title('fig 1. problem ')
plt.show()
plt.close('all')

# fig 2
a_x = x0 + x5
a_y = x00 + x0
b_x = x5 + x0
b_y = x55 + x5
x = [2.5] * 100
y = np.linspace(-0.2, 5.2, 100)
group_a = plt.scatter(a_x, a_y, alpha=0.6)
group_b = plt.scatter(b_x, b_y, alpha=0.6)
plt.plot(x, y, 'g', label='bound')
plt.legend((group_a, group_b), ('group A', 'group B'), bbox_to_anchor=(1.3, 1))
plt.legend()
plt.title('fig 2. linear separable problem')
plt.show()
plt.close('all')

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def step(x):
    tmp = x > 0
    return tmp.astype(int)

def relu(x):
    return np.minimum(np.maximum(0.25 * x, 0), 6)

x = np.linspace(-5, 5, 1000)
y1 = sigmoid(x)
y2 = step(x)
y3 = relu(x)
y4 = np.tanh(x)
y5 = x * x / 25.0
plt.plot(x, y2, label='step')
plt.title('fig 3. Step')
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()
plt.close('all')
plt.plot(x, y1, label='sigmoid')
plt.xlabel('x')
plt.ylabel('y')
plt.title('fig 4. Sigmoid')
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()
plt.close('all')
plt.plot(x, y3, label='relu')
plt.xlabel('x')
plt.ylabel('y')
plt.title('fig 5. ReLU')
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()
plt.close('all')
plt.plot(x, y4, label='tanh')
plt.xlabel('x')
plt.ylabel('y')
plt.title('fig 6. tanh')
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()
plt.close('all')
plt.plot(x, y5, label='squared error')
plt.xlabel('x')
plt.ylabel('y')
plt.title('fig 7. squared error')
plt.legend(bbox_to_anchor=(1.4, 1))
plt.show()
plt.close('all')

# %%
# %matplotlib inline
import numpy as np
import scipy
import matplotlib.pyplot as plt

def gen_random(loc, size):
    return list(np.random.normal(loc=loc, scale=0.25, size=size))

# fig 2
x0, x5, x00, x55 = gen_random(0.0, 100), gen_random(5.0, 100), gen_random(0.0, 100), gen_random(5.0, 100)
a_x = x0 + x5
a_y = x00 + x0
b_x = x5 + x0
b_y = x55 + x5
y = [2.5] * 100
x = np.linspace(-0.2, 5.2, 100)
group_a = plt.scatter(a_x, a_y, alpha=0.6)
group_b = plt.scatter(b_x, b_y, alpha=0.6)
plt.plot(x, y, 'g', label='bound')
plt.legend((group_a, group_b), ('group A', 'group B'), bbox_to_anchor=(1.3, 1))
plt.legend()
plt.title('fig 2. linear separable problem')
plt.savefig('../images/fig_02.png')
plt.show()
plt.close('all')

# %%
x = np.linspace(-5, 5, 100)
y = 0.5 * x + 0.5
plt.plot(x, y, label='linear: y = 0.5 * x + 0.5')
plt.xlabel('x')
plt.ylabel('y')
plt.title('linear')
plt.grid()
plt.savefig('../images/linear.png')
plt.show()

# %%
y = np.exp(x  / 10) - 0.5
y1 = np.cos(x)
plt.plot(x, y, label='exp(0.1 * x) - 0.5')
plt.plot(x, y1, label='cos(x)')
plt.legend()
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.title('non linear')
plt.savefig('../images/non_linear.png')
plt.show()

# %%
x = np.linspace(-5.0, 5.0, 500)
y5 = x * x / 25.0
x
x_list = [-1.0, 3.0]
y_list = [1 / 25.0, 9.0 / 25.0]
plt.plot(x, y5, label='quadratic')
plt.scatter(x_list[0], y_list[0], label='point 1', c='r', s=100)
plt.scatter(x_list[1], y_list[1], label='point 2', c='orange', s=100)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.legend()
plt.show()
